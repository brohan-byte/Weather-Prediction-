# %%
from threading import Thread, Lock
lock = Lock()
def Print(*args):
    with lock:
        print(*args)

# %%
import os, json

for partition in range(6):
    path = f"partition-{partition}.json"
    if os.path.exists(path):
        os.remove(path)

# %%
import datetime, time, random, string

def one_station(name):
    # temp pattern
    month_avg = [27,31,44,58,70,79,83,81,74,61,46,32]
    shift = (random.random()-0.5) * 30
    month_avg = [m + shift + (random.random()-0.5) * 5 for m in month_avg]
    
    # rain pattern
    start_rain = [0.1,0.1,0.3,0.5,0.4,0.2,0.2,0.1,0.2,0.2,0.2,0.1]
    shift = (random.random()-0.5) * 0.1
    start_rain = [r + shift + (random.random() - 0.5) * 0.2 for r in start_rain]
    stop_rain = 0.2 + random.random() * 0.2

    # day's state
    today = datetime.date(2000, 1, 1)
    temp = month_avg[0]
    raining = False
    
    # gen weather
    while True:
        # choose temp+rain
        month = today.month - 1
        temp = temp * 0.8 + month_avg[month] * 0.2 + (random.random()-0.5) * 20
        if temp < 32:
            raining=False
        elif raining and random.random() < stop_rain:
            raining = False
        elif not raining and random.random() < start_rain[month]:
            raining = True

        yield (today.strftime("%Y-%m-%d"), name, temp, raining)

        # next day
        today += datetime.timedelta(days=1)
        
def all_stations(count=10, sleep_sec=1):
    assert count <= 26
    stations = []
    for name in string.ascii_uppercase[:count]:
        stations.append(one_station(name))
    while True:
        for station in stations:
            yield next(station)
        time.sleep(sleep_sec)

# %%
from kafka import KafkaAdminClient, KafkaProducer, KafkaConsumer, TopicPartition
from kafka.admin import NewTopic

from kafka.errors import TopicAlreadyExistsError, UnknownTopicOrPartitionError
broker = "localhost:9092"
admin = KafkaAdminClient(bootstrap_servers=[broker])
print(admin)
try:
    admin.delete_topics(["stations", "stations-json"])
    print("deleted")
except UnknownTopicOrPartitionError:
    print("cannot delete (may not exist yet)")

time.sleep(1)
admin.create_topics([NewTopic("stations", 6, 1)])
admin.create_topics([NewTopic("stations-json", 6, 1)])
admin.list_topics()
# Out:
# <kafka.admin.client.KafkaAdminClient object at 0x1079d34d0>
# deleted
# ['stations']

# %%
# report_pb2 is the result of building report.proto
from report_pb2 import *
# Out:
# /Users/rohan/Desktop/CS/projects/kafka_project/venv/lib/python3.13/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.29.3 is exactly one major version older than the runtime version 6.31.1 at report.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(

# %%
from threading import Thread, Lock
import os, json,threading

# %%
for partition in range(6):
    path = f"partition-{partition}.json"
    if os.path.exists(path):
        os.remove(path)

# %%
def produce():
    producer = KafkaProducer(bootstrap_servers=[broker],acks="all",retries=10)#KafkaProducer(bootstrap_servers=[broker],???)
    Print("generating records")
    for date, station, degrees, raining in all_stations(15):
        json_file = {"date":date,"station":station,"degrees":float(degrees), "raining":int(raining)}
        st = Report(date=date, station=station,degrees=degrees,raining=raining)
        value = st.SerializeToString()
        key = bytes(station,"utf-8")
        future = producer.send("stations", value=value, key=key)
        producer.send("stations-json",value = bytes(json.dumps(json_file),"utf-8"),key = key)
        time.sleep(1)
        # TODO: send to "stations" stream using protobuf
        # TODO: send to "stations-json" using JSON

# TODO: start thread to run produce
threading.Thread(target = produce).start()
# never join thread because we want it to run forever
# Out:
# generating records

# %%
def load_partition(partition_num):
    path = f"partition-{partition_num}.json"
    if os.path.exists(path):
        with open(path, "r") as file:
            return json.load(file)
    else:
        return {"partition": partition_num, "offset": 0, "stations": {}}

def save_partition(partition):
    path = f"partition-{partition['partition']}.json"
    with open(path, "w") as file:
        json.dump(partition, file)

# %%
def consume(part_nums=[], iterations=10):
    consumer = KafkaConsumer(bootstrap_servers=[broker],enable_auto_commit=False)
    # TODO: create list of TopicPartition objects
    consumer.assign([TopicPartition("stations",part) for part in part_nums])
    consumer.assignment()
    # consumer.seek_to_beginning()

    # PART 1: initialization
    partitions = {part:load_partition(part) for part in part_nums} # key=partition num, value=snapshot dict
    Print(partitions)
    # TODO: load partitions from JSON files (if they exist) or create fresh dicts
    for part in partitions:
        consumer.seek(TopicPartition("stations",part),partitions[part].get("offset",0))
        Print("Seeking partition", part, "to offset", partitions[part].get("offset", 0))
    # TODO: if offsets were specified in previous JSON files, the consumer
    #       should seek to those; else, seek to offset 0.

    # PART 2: process batches
    for i in range(iterations):

        batch = consumer.poll(1000) # 1s timeout
        for tp, messages in batch.items():

            snap = partitions[tp.partition]
            for message in messages:
                r = Report.FromString(message.value)
                rec = snap["stations"].setdefault(
                r.station,
                {"sum": 0.0, "count": 0, "avg": 0.0, "start": r.date, "end": r.date}
                )
                if r.date>rec["end"]:
                    rec["sum"] += r.degrees
                    rec["count"]+=1
                    rec["avg"] = rec["sum"]/rec["count"]
                    rec["end"] = r.date

                snap["offset"] = consumer.position(tp)
            save_partition(snap)
            Print(partitions)
                
            # perhaps create a separate function for the following?  You decide.
            # TODO: update the partitions based on new messages
            # TODO: save the data back to the JSON file
    Print("exiting")

for i in range(2):
    print("ROUND", i)
    t1 = threading.Thread(target=consume, args=([0,1], 30))
    t2 = threading.Thread(target=consume, args=([2,3], 30))
    t3 = threading.Thread(target=consume, args=([4,5], 30))
    t1.start()
    t2.start()
    t3.start()
    t1.join()
    t2.join()
    t3.join()
# Out:
# ROUND 0
# {2: {'partition': 2, 'offset': 0, 'stations': {}}, 3: {'partition': 3, 'offset': 0, 'stations': {}}}
# Seeking partition 2 to offset 0
# Seeking partition 3 to offset 0
# {0: {'partition': 0, 'offset': 0, 'stations': {}}, 1: {'partition': 1, 'offset': 0, 'stations': {}}}
# Seeking partition 0 to offset 0
# Seeking partition 1 to offset 0
# {4: {'partition': 4, 'offset': 0, 'stations': {}}, 5: {'partition': 5, 'offset': 0, 'stations': {}}}
# Seeking partition 4 to offset 0
# Seeking partition 5 to offset 0
# {0: {'partition': 0, 'offset': 65, 'stations': {'N': {'sum': 2105.0962896116525, 'count': 64, 'avg': 32.89212952518207, 'start': '2000-01-01', 'end': '2000-03-05'}}}, 1: {'partition': 1, 'offset': 0, 'stations': {}}}
# {4: {'partition': 4, 'offset': 327, 'stations': {'A': {'sum': 2207.196297901064, 'count': 65, 'avg': 33.95686612155483, 'start': '2000-01-01', 'end': '2000-03-06'}, 'B': {'sum': 2804.330841923062, 'count': 65, 'avg': 43.14355141420096, 'start': '2000-01-01', 'end': '2000-03-06'}, 'C': {'sum': 2550.7466137568927, 'count': 64, 'avg': 39.85541583995145, 'start': '2000-01-01', 'end': '2000-03-05'}, 'K': {'sum': 908.0986943187746, 'count': 64, 'avg': 14.189042098730853, 'start': '2000-01-01', 'end': '2000-03-05'}, 'L': {'sum': 1602.5552439366859, 'count': 64, 'avg': 25.039925686510717, 'start': '2000-01-01', 'end': '2000-03-05'}}}, 5: {'partition': 5, 'offset': 0, 'stations': {}}}
# {2: {'partition': 2, 'offset': 195, 'stations': {'F': {'sum': 1090.0058431159273, 'count': 64, 'avg': 17.031341298686364, 'start': '2000-01-01', 'end': '2000-03-05'}, 'I': {'sum': 2717.543779026111, 'count': 64, 'avg': 42.46162154728299, 'start': '2000-01-01', 'end': '2000-03-05'}, 'J': {'sum': 896.9557559730999, 'count': 64, 'avg': 14.014933687079687, 'start': '2000-01-01', 'end': '2000-03-05'}}}, 3: {'partition': 3, 'offset': 0, 'stations': {}}}
# {0: {'partition': 0, 'offset': 65, 'stations': {'N': {'sum': 2105.0962896116525, 'count': 64, 'avg': 32.89212952518207, 'start': '2000-01-01', 'end': '2000-03-05'}}}, 1: {'partition': 1, 'offset': 130, 'stations': {'E': {'sum': 2156.094711064353, 'count': 64, 'avg': 33.68897986038051, 'start': '2000-01-01', 'end': '2000-03-05'}, 'O': {'sum': 1653.4388915590207, 'count': 64, 'avg': 25.8349826806097, 'start': '2000-01-01', 'end': '2000-03-05'}}}}
# {4: {'partition': 4, 'offset': 327, 'stations': {'A': {'sum': 2207.196297901064, 'count': 65, 'avg': 33.95686612155483, 'start': '2000-01-01', 'end': '2000-03-06'}, 'B': {'sum': 2804.330841923062, 'count': 65, 'avg': 43.14355141420096, 'start': '2000-01-01', 'end': '2000-03-06'}, 'C': {'sum': 2550.7466137568927, 'count': 64, 'avg': 39.85541583995145, 'start': '2000-01-01', 'end': '2000-03-05'}, 'K': {'sum': 908.0986943187746, 'count': 64, 'avg': 14.189042098730853, 'start': '2000-01-01', 'end': '2000-03-05'}, 'L': {'sum': 1602.5552439366859, 'count': 64, 'avg': 25.039925686510717, 'start': '2000-01-01', 'end': '2000-03-05'}}}, 5: {'partition': 5, 'offset': 65, 'stations': {'H': {'sum': 1228.2757687887972, 'count': 64, 'avg': 19.191808887324957, 'start': '2000-01-01', 'end': '2000-03-05'}}}}
# {2: {'partition': 2, 'offset': 195, 'stations': {'F': {'sum': 1090.0058431159273, 'count': 64, 'avg': 17.031341298686364, 'start': '2000-01-01', 'end': '2000-03-05'}, 'I': {'sum': 2717.543779026111, 'count': 64, 'avg': 42.46162154728299, 'start': '2000-01-01', 'end': '2000-03-05'}, 'J': {'sum': 896.9557559730999, 'count': 64, 'avg': 14.014933687079687, 'start': '2000-01-01', 'end': '2000-03-05'}}}, 3: {'partition': 3, 'offset': 195, 'stations': {'D': {'sum': 1663.3952809893933, 'count': 64, 'avg': 25.99055126545927, 'start': '2000-01-01', 'end': '2000-03-05'}, 'G': {'sum': 1804.622825808311, 'count': 64, 'avg': 28.19723165325486, 'start': '2000-01-01', 'end': '2000-03-05'}, 'M': {'sum': 1410.0512219378168, 'count': 64, 'avg': 22.032050342778387, 'start': '2000-01-01', 'end': '2000-03-05'}}}}
# {4: {'partition': 4, 'offset': 328, 'stations': {'A': {'sum': 2207.196297901064, 'count': 65, 'avg': 33.95686612155483, 'start': '2000-01-01', 'end': '2000-03-06'}, 'B': {'sum': 2804.330841923062, 'count': 65, 'avg': 43.14355141420096, 'start': '2000-01-01', 'end': '2000-03-06'}, 'C': {'sum': 2607.562084241883, 'count': 65, 'avg': 40.11633975756743, 'start': '2000-01-01', 'end': '2000-03-06'}, 'K': {'sum': 908.0986943187746, 'count': 64, 'avg': 14.189042098730853, 'start': '2000-01-01', 'end': '2000-03-05'}, 'L': {'sum': 1602.5552439366859, 'count': 64, 'avg': 25.039925686510717, 'start': '2000-01-01', 'end': '2000-03-05'}}}, 5: {'partition': 5, 'offset': 65, 'stations': {'H': {'sum': 1228.2757687887972, 'count': 64, 'avg': 19.191808887324957, 'start': '2000-01-01', 'end': '2000-03-05'}}}}
# {2: {'partition': 2, 'offset': 195, 'stations': {'F': {'sum': 1090.0058431159273, 'count': 64, 'avg': 17.031341298686364, 'start': '2000-01-01', 'end': '2000-03-05'}, 'I': {'sum': 2717.543779026111, 'count': 64, 'avg': 42.46162154728299, 'start': '2000-01-01', 'end': '2000-03-05'}, 'J': {'sum': 896.9557559730999, 'count': 64, 'avg': 14.014933687079687, 'start': '2000-01-01', 'end': '2000-03-05'}}}, 3: {'partition': 3, 'offset': 196, 'stations': {'D': {'sum': 1717.9449036143035, 'count': 65, 'avg': 26.429921594066208, 'start': '2000-01-01', 'end': '2000-03-06'}, 'G': {'sum': 1804.622825808311, 'count': 64, 'avg': 28.19723165325486, 'start': '2000-01-01', 'end': '2000-03-05'}, 'M': {'sum': 1410.0512219378168, 'count': 64, 'avg': 22.032050342778387, 'start': '2000-01-01', 'end': '2000-03-05'}}}}
# {0: {'partition': 0, 'offset': 65, 'stations': {'N': {'sum': 2105.0962896116525, 'count': 64, 'avg': 32.89212952518207, 'start': '2000-01-01', 'end': '2000-03-05'}}}, 1: {'partition': 1, 'offset': 131, 'stations': {'E': {'sum': 2189.423241681994, 'count': 65, 'avg': 33.6834344874153, 'start': '2000-01-01', 'end': '2000-03-06'}, 'O': {'sum': 1653.4388915590207, 'count': 64, 'avg': 25.8349826806097, 'start': '2000-01-01', 'end': '2000-03-05'}}}}
# {2: {'partition': 2, 'offset': 196, 'stations': {'F': {'sum': 1128.5976949299725, 'count': 65, 'avg': 17.363041460461115, 'start': '2000-01-01', 'end': '2000-03-06'}, 'I': {'sum': 2717.543779026111, 'count': 64, 'avg': 42.46162154728299, 'start': '2000-01-01', 'end': '2000-03-05'}, 'J': {'sum': 896.9557559730999, 'count': 64, 'avg': 14.014933687079687, 'start': '2000-01-01', 'end': '2000-03-05'}}}, 3: {'partition': 3, 'offset': 196, 'stations': {'D': {'sum': 1717.9449036143035, 'count': 65, 'avg': 26.429921594066208, 'start': '2000-01-01', 'end': '2000-03-06'}, 'G': {'sum': 1804.622825808311, 'count': 64, 'avg': 28.19723165325486, 'start': '2000-01-01', 'end': '2000-03-05'}, 'M': {'sum': 1410.0512219378168, 'count': 64, 'avg': 22.032050342778387, 'start': '2000-01-01', 'end': '2000-03-05'}}}}
# {2: {'partition': 2, 'offset': 196, 'stations': {'F': {'sum': 1128.5976949299725, 'count': 65, 'avg': 17.363041460461115, 'start': '2000-01-01', 'end': '2000-03-06'}, 'I': {'sum': 2717.543779026111, 'count': 64, 'avg': 42.46162154728299, 'start': '2000-01-01', 'end': '2000-03-05'}, 'J': {'sum': 896.9557559730999, 'count': 64, 'avg': 14.014933687079687, 'start': '2000-01-01', 'end': '2000-03-05'}}}, 3: {'partition': 3, 'offset': 197, 'stations': {'D': {'sum': 1717.9449036143035, 'count': 65, 'avg': 26.429921594066208, 'start': '2000-01-01', 'end': '2000-03-06'}, 'G': {'sum': 1840.9140471719106, 'count': 65, 'avg': 28.321754571875548, 'start': '2000-01-01', 'end': '2000-03-06'}, 'M': {'sum': 1410.0512219378168, 'count': 64, 'avg': 22.032050342778387, 'start': '2000-01-01', 'end': '2000-03-05'}}}}
# {4: {'partition': 4, 'offset': 328, 'stations': {'A': {'sum': 2207.196297901064, 'count': 65, 'avg': 33.95686612155483, 'start': '2000-01-01', 'end': '2000-03-06'}, 'B': {'sum': 2804.330841923062, 'count': 65, 'avg': 43.14355141420096, 'start': '2000-01-01', 'end': '2000-03-06'}, 'C': {'sum': 2607.562084241883, 'count': 65, 'avg': 40.11633975756743, 'start': '2000-01-01', 'end': '2000-03-06'}, 'K': {'sum': 908.0986943187746, 'count': 64, 'avg': 14.189042098730853, 'start': '2000-01-01', 'end': '2000-03-05'}, 'L': {'sum': 1602.5552439366859, 'count': 64, 'avg': 25.039925686510717, 'start': '2000-01-01', 'end': '2000-03-05'}}}, 5: {'partition': 5, 'offset': 66, 'stations': {'H': {'sum': 1272.9030525407825, 'count': 65, 'avg': 19.583123885242806, 'start': '2000-01-01', 'end': '2000-03-06'}}}}
# {2: {'partition': 2, 'offset': 197, 'stations': {'F': {'sum': 1128.5976949299725, 'count': 65, 'avg': 17.363041460461115, 'start': '2000-01-01', 'end': '2000-03-06'}, 'I': {'sum': 2766.1523267036746, 'count': 65, 'avg': 42.55618964159499, 'start': '2000-01-01', 'end': '2000-03-06'}, 'J': {'sum': 896.9557559730999, 'count': 64, 'avg': 14.014933687079687, 'start': '2000-01-01', 'end': '2000-03-05'}}}, 3: {'partition': 3, 'offset': 197, 'stations': {'D': {'sum': 1717.9449036143035, 'count': 65, 'avg': 26.429921594066208, 'start': '2000-01-01', 'end': '2000-03-06'}, 'G': {'sum': 1840.9140471719106, 'count': 65, 'avg': 28.321754571875548, 'start': '2000-01-01', 'end': '2000-03-06'}, 'M': {'sum': 1410.0512219378168, 'count': 64, 'avg': 22.032050342778387, 'start': '2000-01-01', 'end': '2000-03-05'}}}}
# {2: {'partition': 2, 'offset': 198, 'stations': {'F': {'sum': 1128.5976949299725, 'count': 65, 'avg': 17.363041460461115, 'start': '2000-01-01', 'end': '2000-03-06'}, 'I': {'sum': 2766.1523267036746, 'count': 65, 'avg': 42.55618964159499, 'start': '2000-01-01', 'end': '2000-03-06'}, 'J': {'sum': 926.0530825281049, 'count': 65, 'avg': 14.246970500432383, 'start': '2000-01-01', 'end': '2000-03-06'}}}, 3: {'partition': 3, 'offset': 197, 'stations': {'D': {'sum': 1717.9449036143035, 'count': 65, 'avg': 26.429921594066208, 'start': '2000-01-01', 'end': '2000-03-06'}, 'G': {'sum': 1840.9140471719106, 'count': 65, 'avg': 28.321754571875548, 'start': '2000-01-01', 'end': '2000-03-06'}, 'M': {'sum': 1410.0512219378168, 'count': 64, 'avg': 22.032050342778387, 'start': '2000-01-01', 'end': '2000-03-05'}}}}
# {4: {'partition': 4, 'offset': 329, 'stations': {'A': {'sum': 2207.196297901064, 'count': 65, 'avg': 33.95686612155483, 'start': '2000-01-01', 'end': '2000-03-06'}, 'B': {'sum': 2804.330841923062, 'count': 65, 'avg': 43.14355141420096, 'start': '2000-01-01', 'end': '2000-03-06'}, 'C': {'sum': 2607.562084241883, 'count': 65, 'avg': 40.11633975756743, 'start': '2000-01-01', 'end': '2000-03-06'}, 'K': {'sum': 921.3916105921172, 'count': 65, 'avg': 14.175255547571034, 'start': '2000-01-01', 'end': '2000-03-06'}, 'L': {'sum': 1602.5552439366859, 'count': 64, 'avg': 25.039925686510717, 'start': '2000-01-01', 'end': '2000-03-05'}}}, 5: {'partition': 5, 'offset': 66, 'stations': {'H': {'sum': 1272.9030525407825, 'count': 65, 'avg': 19.583123885242806, 'start': '2000-01-01', 'end': '2000-03-06'}}}}
# {4: {'partition': 4, 'offset': 330, 'stations': {'A': {'sum': 2207.196297901064, 'count': 65, 'avg': 33.95686612155483, 'start': '2000-01-01', 'end': '2000-03-06'}, 'B': {'sum': 2804.330841923062, 'count': 65, 'avg': 43.14355141420096, 'start': '2000-01-01', 'end': '2000-03-06'}, 'C': {'sum': 2607.562084241883, 'count': 65, 'avg': 40.11633975756743, 'start': '2000-01-01', 'end': '2000-03-06'}, 'K': {'sum': 921.3916105921172, 'count': 65, 'avg': 14.175255547571034, 'start': '2000-01-01', 'end': '2000-03-06'}, 'L': {'sum': 1630.3297189121117, 'count': 65, 'avg': 25.08199567557095, 'start': '2000-01-01', 'end': '2000-03-06'}}}, 5: {'partition': 5, 'offset': 66, 'stations': {'H': {'sum': 1272.9030525407825, 'count': 65, 'avg': 19.583123885242806, 'start': '2000-01-01', 'end': '2000-03-06'}}}}
# {2: {'partition': 2, 'offset': 198, 'stations': {'F': {'sum': 1128.5976949299725, 'count': 65, 'avg': 17.363041460461115, 'start': '2000-01-01', 'end': '2000-03-06'}, 'I': {'sum': 2766.1523267036746, 'count': 65, 'avg': 42.55618964159499, 'start': '2000-01-01', 'end': '2000-03-06'}, 'J': {'sum': 926.0530825281049, 'count': 65, 'avg': 14.246970500432383, 'start': '2000-01-01', 'end': '2000-03-06'}}}, 3: {'partition': 3, 'offset': 198, 'stations': {'D': {'sum': 1717.9449036143035, 'count': 65, 'avg': 26.429921594066208, 'start': '2000-01-01', 'end': '2000-03-06'}, 'G': {'sum': 1840.9140471719106, 'count': 65, 'avg': 28.321754571875548, 'start': '2000-01-01', 'end': '2000-03-06'}, 'M': {'sum': 1436.4709904592266, 'count': 65, 'avg': 22.099553699372716, 'start': '2000-01-01', 'end': '2000-03-06'}}}}
# {0: {'partition': 0, 'offset': 66, 'stations': {'N': {'sum': 2151.0102528613315, 'count': 65, 'avg': 33.09246542863587, 'start': '2000-01-01', 'end': '2000-03-06'}}}, 1: {'partition': 1, 'offset': 131, 'stations': {'E': {'sum': 2189.423241681994, 'count': 65, 'avg': 33.6834344874153, 'start': '2000-01-01', 'end': '2000-03-06'}, 'O': {'sum': 1653.4388915590207, 'count': 64, 'avg': 25.8349826806097, 'start': '2000-01-01', 'end': '2000-03-05'}}}}
# {0: {'partition': 0, 'offset': 66, 'stations': {'N': {'sum': 2151.0102528613315, 'count': 65, 'avg': 33.09246542863587, 'start': '2000-01-01', 'end': '2000-03-06'}}}, 1: {'partition': 1, 'offset': 132, 'stations': {'E': {'sum': 2189.423241681994, 'count': 65, 'avg': 33.6834344874153, 'start': '2000-01-01', 'end': '2000-03-06'}, 'O': {'sum': 1690.1609887704199, 'count': 65, 'avg': 26.002476750314152, 'start': '2000-01-01', 'end': '2000-03-06'}}}}
# {4: {'partition': 4, 'offset': 331, 'stations': {'A': {'sum': 2253.3626515806313, 'count': 66, 'avg': 34.141858357282295, 'start': '2000-01-01', 'end': '2000-03-07'}, 'B': {'sum': 2804.330841923062, 'count': 65, 'avg': 43.14355141420096, 'start': '2000-01-01', 'end': '2000-03-06'}, 'C': {'sum': 2607.562084241883, 'count': 65, 'avg': 40.11633975756743, 'start': '2000-01-01', 'end': '2000-03-06'}, 'K': {'sum': 921.3916105921172, 'count': 65, 'avg': 14.175255547571034, 'start': '2000-01-01', 'end': '2000-03-06'}, 'L': {'sum': 1630.3297189121117, 'count': 65, 'avg': 25.08199567557095, 'start': '2000-01-01', 'end': '2000-03-06'}}}, 5: {'partition': 5, 'offset': 66, 'stations': {'H': {'sum': 1272.9030525407825, 'count': 65, 'avg': 19.583123885242806, 'start': '2000-01-01', 'end': '2000-03-06'}}}}
# {4: {'partition': 4, 'offset': 332, 'stations': {'A': {'sum': 2253.3626515806313, 'count': 66, 'avg': 34.141858357282295, 'start': '2000-01-01', 'end': '2000-03-07'}, 'B': {'sum': 2849.0752021313815, 'count': 66, 'avg': 43.16780609289972, 'start': '2000-01-01', 'end': '2000-03-07'}, 'C': {'sum': 2607.562084241883, 'count': 65, 'avg': 40.11633975756743, 'start': '2000-01-01', 'end': '2000-03-06'}, 'K': {'sum': 921.3916105921172, 'count': 65, 'avg': 14.175255547571034, 'start': '2000-01-01', 'end': '2000-03-06'}, 'L': {'sum': 1630.3297189121117, 'count': 65, 'avg': 25.08199567557095, 'start': '2000-01-01', 'end': '2000-03-06'}}}, 5: {'partition': 5, 'offset': 66, 'stations': {'H': {'sum': 1272.9030525407825, 'count': 65, 'avg': 19.583123885242806, 'start': '2000-01-01', 'end': '2000-03-06'}}}}
# {4: {'partition': 4, 'offset': 333, 'stations': {'A': {'sum': 2253.3626515806313, 'count': 66, 'avg': 34.141858357282295, 'start': '2000-01-01', 'end': '2000-03-07'}, 'B': {'sum': 2849.0752021313815, 'count': 66, 'avg': 43.16780609289972, 'start': '2000-01-01', 'end': '2000-03-07'}, 'C': {'sum': 2667.2302570806096, 'count': 66, 'avg': 40.41257965273651, 'start': '2000-01-01', 'end': '2000-03-07'}, 'K': {'sum': 921.3916105921172, 'count': 65, 'avg': 14.175255547571034, 'start': '2000-01-01', 'end': '2000-03-06'}, 'L': {'sum': 1630.3297189121117, 'count': 65, 'avg': 25.08199567557095, 'start': '2000-01-01', 'end': '2000-03-06'}}}, 5: {'partition': 5, 'offset': 66, 'stations': {'H': {'sum': 1272.9030525407825, 'count': 65, 'avg': 19.583123885242806, 'start': '2000-01-01', 'end': '2000-03-06'}}}}
# {2: {'partition': 2, 'offset': 198, 'stations': {'F': {'sum': 1128.5976949299725, 'count': 65, 'avg': 17.363041460461115, 'start': '2000-01-01', 'end': '2000-03-06'}, 'I': {'sum': 2766.1523267036746, 'count': 65, 'avg': 42.55618964159499, 'start': '2000-01-01', 'end': '2000-03-06'}, 'J': {'sum': 926.0530825281049, 'count': 65, 'avg': 14.246970500432383, 'start': '2000-01-01', 'end': '2000-03-06'}}}, 3: {'partition': 3, 'offset': 199, 'stations': {'D': {'sum': 1761.8877340319598, 'count': 66, 'avg': 26.695268697453937, 'start': '2000-01-01', 'end': '2000-03-07'}, 'G': {'sum': 1840.9140471719106, 'count': 65, 'avg': 28.321754571875548, 'start': '2000-01-01', 'end': '2000-03-06'}, 'M': {'sum': 1436.4709904592266, 'count': 65, 'avg': 22.099553699372716, 'start': '2000-01-01', 'end': '2000-03-06'}}}}
# {0: {'partition': 0, 'offset': 66, 'stations': {'N': {'sum': 2151.0102528613315, 'count': 65, 'avg': 33.09246542863587, 'start': '2000-01-01', 'end': '2000-03-06'}}}, 1: {'partition': 1, 'offset': 133, 'stations': {'E': {'sum': 2231.253561648659, 'count': 66, 'avg': 33.8068721461918, 'start': '2000-01-01', 'end': '2000-03-07'}, 'O': {'sum': 1690.1609887704199, 'count': 65, 'avg': 26.002476750314152, 'start': '2000-01-01', 'end': '2000-03-06'}}}}
# {2: {'partition': 2, 'offset': 199, 'stations': {'F': {'sum': 1158.0042720544586, 'count': 66, 'avg': 17.545519273552404, 'start': '2000-01-01', 'end': '2000-03-07'}, 'I': {'sum': 2766.1523267036746, 'count': 65, 'avg': 42.55618964159499, 'start': '2000-01-01', 'end': '2000-03-06'}, 'J': {'sum': 926.0530825281049, 'count': 65, 'avg': 14.246970500432383, 'start': '2000-01-01', 'end': '2000-03-06'}}}, 3: {'partition': 3, 'offset': 199, 'stations': {'D': {'sum': 1761.8877340319598, 'count': 66, 'avg': 26.695268697453937, 'start': '2000-01-01', 'end': '2000-03-07'}, 'G': {'sum': 1840.9140471719106, 'count': 65, 'avg': 28.321754571875548, 'start': '2000-01-01', 'end': '2000-03-06'}, 'M': {'sum': 1436.4709904592266, 'count': 65, 'avg': 22.099553699372716, 'start': '2000-01-01', 'end': '2000-03-06'}}}}
# {2: {'partition': 2, 'offset': 199, 'stations': {'F': {'sum': 1158.0042720544586, 'count': 66, 'avg': 17.545519273552404, 'start': '2000-01-01', 'end': '2000-03-07'}, 'I': {'sum': 2766.1523267036746, 'count': 65, 'avg': 42.55618964159499, 'start': '2000-01-01', 'end': '2000-03-06'}, 'J': {'sum': 926.0530825281049, 'count': 65, 'avg': 14.246970500432383, 'start': '2000-01-01', 'end': '2000-03-06'}}}, 3: {'partition': 3, 'offset': 200, 'stations': {'D': {'sum': 1761.8877340319598, 'count': 66, 'avg': 26.695268697453937, 'start': '2000-01-01', 'end': '2000-03-07'}, 'G': {'sum': 1874.1214303924266, 'count': 66, 'avg': 28.3957792483701, 'start': '2000-01-01', 'end': '2000-03-07'}, 'M': {'sum': 1436.4709904592266, 'count': 65, 'avg': 22.099553699372716, 'start': '2000-01-01', 'end': '2000-03-06'}}}}
# exiting
# {4: {'partition': 4, 'offset': 333, 'stations': {'A': {'sum': 2253.3626515806313, 'count': 66, 'avg': 34.141858357282295, 'start': '2000-01-01', 'end': '2000-03-07'}, 'B': {'sum': 2849.0752021313815, 'count': 66, 'avg': 43.16780609289972, 'start': '2000-01-01', 'end': '2000-03-07'}, 'C': {'sum': 2667.2302570806096, 'count': 66, 'avg': 40.41257965273651, 'start': '2000-01-01', 'end': '2000-03-07'}, 'K': {'sum': 921.3916105921172, 'count': 65, 'avg': 14.175255547571034, 'start': '2000-01-01', 'end': '2000-03-06'}, 'L': {'sum': 1630.3297189121117, 'count': 65, 'avg': 25.08199567557095, 'start': '2000-01-01', 'end': '2000-03-06'}}}, 5: {'partition': 5, 'offset': 67, 'stations': {'H': {'sum': 1318.802534042306, 'count': 66, 'avg': 19.981856576398574, 'start': '2000-01-01', 'end': '2000-03-07'}}}}
# exiting
# exiting
# ROUND 1
# {4: {'partition': 4, 'offset': 333, 'stations': {'A': {'sum': 2253.3626515806313, 'count': 66, 'avg': 34.141858357282295, 'start': '2000-01-01', 'end': '2000-03-07'}, 'B': {'sum': 2849.0752021313815, 'count': 66, 'avg': 43.16780609289972, 'start': '2000-01-01', 'end': '2000-03-07'}, 'C': {'sum': 2667.2302570806096, 'count': 66, 'avg': 40.41257965273651, 'start': '2000-01-01', 'end': '2000-03-07'}, 'K': {'sum': 921.3916105921172, 'count': 65, 'avg': 14.175255547571034, 'start': '2000-01-01', 'end': '2000-03-06'}, 'L': {'sum': 1630.3297189121117, 'count': 65, 'avg': 25.08199567557095, 'start': '2000-01-01', 'end': '2000-03-06'}}}, 5: {'partition': 5, 'offset': 67, 'stations': {'H': {'sum': 1318.802534042306, 'count': 66, 'avg': 19.981856576398574, 'start': '2000-01-01', 'end': '2000-03-07'}}}}
# Seeking partition 4 to offset 333
# Seeking partition 5 to offset 67
# {2: {'partition': 2, 'offset': 199, 'stations': {'F': {'sum': 1158.0042720544586, 'count': 66, 'avg': 17.545519273552404, 'start': '2000-01-01', 'end': '2000-03-07'}, 'I': {'sum': 2766.1523267036746, 'count': 65, 'avg': 42.55618964159499, 'start': '2000-01-01', 'end': '2000-03-06'}, 'J': {'sum': 926.0530825281049, 'count': 65, 'avg': 14.246970500432383, 'start': '2000-01-01', 'end': '2000-03-06'}}}, 3: {'partition': 3, 'offset': 200, 'stations': {'D': {'sum': 1761.8877340319598, 'count': 66, 'avg': 26.695268697453937, 'start': '2000-01-01', 'end': '2000-03-07'}, 'G': {'sum': 1874.1214303924266, 'count': 66, 'avg': 28.3957792483701, 'start': '2000-01-01', 'end': '2000-03-07'}, 'M': {'sum': 1436.4709904592266, 'count': 65, 'avg': 22.099553699372716, 'start': '2000-01-01', 'end': '2000-03-06'}}}}
# Seeking partition 2 to offset 199
# Seeking partition 3 to offset 200
# {0: {'partition': 0, 'offset': 66, 'stations': {'N': {'sum': 2151.0102528613315, 'count': 65, 'avg': 33.09246542863587, 'start': '2000-01-01', 'end': '2000-03-06'}}}, 1: {'partition': 1, 'offset': 133, 'stations': {'E': {'sum': 2231.253561648659, 'count': 66, 'avg': 33.8068721461918, 'start': '2000-01-01', 'end': '2000-03-07'}, 'O': {'sum': 1690.1609887704199, 'count': 65, 'avg': 26.002476750314152, 'start': '2000-01-01', 'end': '2000-03-06'}}}}
# Seeking partition 0 to offset 66
# Seeking partition 1 to offset 133
# {4: {'partition': 4, 'offset': 334, 'stations': {'A': {'sum': 2253.3626515806313, 'count': 66, 'avg': 34.141858357282295, 'start': '2000-01-01', 'end': '2000-03-07'}, 'B': {'sum': 2849.0752021313815, 'count': 66, 'avg': 43.16780609289972, 'start': '2000-01-01', 'end': '2000-03-07'}, 'C': {'sum': 2667.2302570806096, 'count': 66, 'avg': 40.41257965273651, 'start': '2000-01-01', 'end': '2000-03-07'}, 'K': {'sum': 945.9533605382718, 'count': 66, 'avg': 14.3326266748223, 'start': '2000-01-01', 'end': '2000-03-07'}, 'L': {'sum': 1630.3297189121117, 'count': 65, 'avg': 25.08199567557095, 'start': '2000-01-01', 'end': '2000-03-06'}}}, 5: {'partition': 5, 'offset': 67, 'stations': {'H': {'sum': 1318.802534042306, 'count': 66, 'avg': 19.981856576398574, 'start': '2000-01-01', 'end': '2000-03-07'}}}}
# {2: {'partition': 2, 'offset': 201, 'stations': {'F': {'sum': 1158.0042720544586, 'count': 66, 'avg': 17.545519273552404, 'start': '2000-01-01', 'end': '2000-03-07'}, 'I': {'sum': 2815.577672231135, 'count': 66, 'avg': 42.6602677610778, 'start': '2000-01-01', 'end': '2000-03-07'}, 'J': {'sum': 946.0097235007898, 'count': 66, 'avg': 14.333480659102877, 'start': '2000-01-01', 'end': '2000-03-07'}}}, 3: {'partition': 3, 'offset': 200, 'stations': {'D': {'sum': 1761.8877340319598, 'count': 66, 'avg': 26.695268697453937, 'start': '2000-01-01', 'end': '2000-03-07'}, 'G': {'sum': 1874.1214303924266, 'count': 66, 'avg': 28.3957792483701, 'start': '2000-01-01', 'end': '2000-03-07'}, 'M': {'sum': 1436.4709904592266, 'count': 65, 'avg': 22.099553699372716, 'start': '2000-01-01', 'end': '2000-03-06'}}}}
# {4: {'partition': 4, 'offset': 335, 'stations': {'A': {'sum': 2253.3626515806313, 'count': 66, 'avg': 34.141858357282295, 'start': '2000-01-01', 'end': '2000-03-07'}, 'B': {'sum': 2849.0752021313815, 'count': 66, 'avg': 43.16780609289972, 'start': '2000-01-01', 'end': '2000-03-07'}, 'C': {'sum': 2667.2302570806096, 'count': 66, 'avg': 40.41257965273651, 'start': '2000-01-01', 'end': '2000-03-07'}, 'K': {'sum': 945.9533605382718, 'count': 66, 'avg': 14.3326266748223, 'start': '2000-01-01', 'end': '2000-03-07'}, 'L': {'sum': 1660.9641014656956, 'count': 66, 'avg': 25.166122749480238, 'start': '2000-01-01', 'end': '2000-03-07'}}}, 5: {'partition': 5, 'offset': 67, 'stations': {'H': {'sum': 1318.802534042306, 'count': 66, 'avg': 19.981856576398574, 'start': '2000-01-01', 'end': '2000-03-07'}}}}
# {2: {'partition': 2, 'offset': 201, 'stations': {'F': {'sum': 1158.0042720544586, 'count': 66, 'avg': 17.545519273552404, 'start': '2000-01-01', 'end': '2000-03-07'}, 'I': {'sum': 2815.577672231135, 'count': 66, 'avg': 42.6602677610778, 'start': '2000-01-01', 'end': '2000-03-07'}, 'J': {'sum': 946.0097235007898, 'count': 66, 'avg': 14.333480659102877, 'start': '2000-01-01', 'end': '2000-03-07'}}}, 3: {'partition': 3, 'offset': 201, 'stations': {'D': {'sum': 1761.8877340319598, 'count': 66, 'avg': 26.695268697453937, 'start': '2000-01-01', 'end': '2000-03-07'}, 'G': {'sum': 1874.1214303924266, 'count': 66, 'avg': 28.3957792483701, 'start': '2000-01-01', 'end': '2000-03-07'}, 'M': {'sum': 1455.9522352801282, 'count': 66, 'avg': 22.059882352729215, 'start': '2000-01-01', 'end': '2000-03-07'}}}}
# {0: {'partition': 0, 'offset': 67, 'stations': {'N': {'sum': 2191.7881113104045, 'count': 66, 'avg': 33.20891077743037, 'start': '2000-01-01', 'end': '2000-03-07'}}}, 1: {'partition': 1, 'offset': 133, 'stations': {'E': {'sum': 2231.253561648659, 'count': 66, 'avg': 33.8068721461918, 'start': '2000-01-01', 'end': '2000-03-07'}, 'O': {'sum': 1690.1609887704199, 'count': 65, 'avg': 26.002476750314152, 'start': '2000-01-01', 'end': '2000-03-06'}}}}
# {0: {'partition': 0, 'offset': 67, 'stations': {'N': {'sum': 2191.7881113104045, 'count': 66, 'avg': 33.20891077743037, 'start': '2000-01-01', 'end': '2000-03-07'}}}, 1: {'partition': 1, 'offset': 134, 'stations': {'E': {'sum': 2231.253561648659, 'count': 66, 'avg': 33.8068721461918, 'start': '2000-01-01', 'end': '2000-03-07'}, 'O': {'sum': 1724.1513799743482, 'count': 66, 'avg': 26.123505757187093, 'start': '2000-01-01', 'end': '2000-03-07'}}}}
# {4: {'partition': 4, 'offset': 336, 'stations': {'A': {'sum': 2295.820809755785, 'count': 67, 'avg': 34.26598223516097, 'start': '2000-01-01', 'end': '2000-03-08'}, 'B': {'sum': 2849.0752021313815, 'count': 66, 'avg': 43.16780609289972, 'start': '2000-01-01', 'end': '2000-03-07'}, 'C': {'sum': 2667.2302570806096, 'count': 66, 'avg': 40.41257965273651, 'start': '2000-01-01', 'end': '2000-03-07'}, 'K': {'sum': 945.9533605382718, 'count': 66, 'avg': 14.3326266748223, 'start': '2000-01-01', 'end': '2000-03-07'}, 'L': {'sum': 1660.9641014656956, 'count': 66, 'avg': 25.166122749480238, 'start': '2000-01-01', 'end': '2000-03-07'}}}, 5: {'partition': 5, 'offset': 67, 'stations': {'H': {'sum': 1318.802534042306, 'count': 66, 'avg': 19.981856576398574, 'start': '2000-01-01', 'end': '2000-03-07'}}}}
# {4: {'partition': 4, 'offset': 337, 'stations': {'A': {'sum': 2295.820809755785, 'count': 67, 'avg': 34.26598223516097, 'start': '2000-01-01', 'end': '2000-03-08'}, 'B': {'sum': 2890.1276148905476, 'count': 67, 'avg': 43.13623305806787, 'start': '2000-01-01', 'end': '2000-03-08'}, 'C': {'sum': 2667.2302570806096, 'count': 66, 'avg': 40.41257965273651, 'start': '2000-01-01', 'end': '2000-03-07'}, 'K': {'sum': 945.9533605382718, 'count': 66, 'avg': 14.3326266748223, 'start': '2000-01-01', 'end': '2000-03-07'}, 'L': {'sum': 1660.9641014656956, 'count': 66, 'avg': 25.166122749480238, 'start': '2000-01-01', 'end': '2000-03-07'}}}, 5: {'partition': 5, 'offset': 67, 'stations': {'H': {'sum': 1318.802534042306, 'count': 66, 'avg': 19.981856576398574, 'start': '2000-01-01', 'end': '2000-03-07'}}}}
# {4: {'partition': 4, 'offset': 338, 'stations': {'A': {'sum': 2295.820809755785, 'count': 67, 'avg': 34.26598223516097, 'start': '2000-01-01', 'end': '2000-03-08'}, 'B': {'sum': 2890.1276148905476, 'count': 67, 'avg': 43.13623305806787, 'start': '2000-01-01', 'end': '2000-03-08'}, 'C': {'sum': 2728.426837693293, 'count': 67, 'avg': 40.72278862228795, 'start': '2000-01-01', 'end': '2000-03-08'}, 'K': {'sum': 945.9533605382718, 'count': 66, 'avg': 14.3326266748223, 'start': '2000-01-01', 'end': '2000-03-07'}, 'L': {'sum': 1660.9641014656956, 'count': 66, 'avg': 25.166122749480238, 'start': '2000-01-01', 'end': '2000-03-07'}}}, 5: {'partition': 5, 'offset': 67, 'stations': {'H': {'sum': 1318.802534042306, 'count': 66, 'avg': 19.981856576398574, 'start': '2000-01-01', 'end': '2000-03-07'}}}}
# {2: {'partition': 2, 'offset': 201, 'stations': {'F': {'sum': 1158.0042720544586, 'count': 66, 'avg': 17.545519273552404, 'start': '2000-01-01', 'end': '2000-03-07'}, 'I': {'sum': 2815.577672231135, 'count': 66, 'avg': 42.6602677610778, 'start': '2000-01-01', 'end': '2000-03-07'}, 'J': {'sum': 946.0097235007898, 'count': 66, 'avg': 14.333480659102877, 'start': '2000-01-01', 'end': '2000-03-07'}}}, 3: {'partition': 3, 'offset': 202, 'stations': {'D': {'sum': 1796.3902509311622, 'count': 67, 'avg': 26.811794790017345, 'start': '2000-01-01', 'end': '2000-03-08'}, 'G': {'sum': 1874.1214303924266, 'count': 66, 'avg': 28.3957792483701, 'start': '2000-01-01', 'end': '2000-03-07'}, 'M': {'sum': 1455.9522352801282, 'count': 66, 'avg': 22.059882352729215, 'start': '2000-01-01', 'end': '2000-03-07'}}}}
# {0: {'partition': 0, 'offset': 67, 'stations': {'N': {'sum': 2191.7881113104045, 'count': 66, 'avg': 33.20891077743037, 'start': '2000-01-01', 'end': '2000-03-07'}}}, 1: {'partition': 1, 'offset': 135, 'stations': {'E': {'sum': 2265.9915975855906, 'count': 67, 'avg': 33.82077011321777, 'start': '2000-01-01', 'end': '2000-03-08'}, 'O': {'sum': 1724.1513799743482, 'count': 66, 'avg': 26.123505757187093, 'start': '2000-01-01', 'end': '2000-03-07'}}}}
# {2: {'partition': 2, 'offset': 202, 'stations': {'F': {'sum': 1189.508882214415, 'count': 67, 'avg': 17.753863913647987, 'start': '2000-01-01', 'end': '2000-03-08'}, 'I': {'sum': 2815.577672231135, 'count': 66, 'avg': 42.6602677610778, 'start': '2000-01-01', 'end': '2000-03-07'}, 'J': {'sum': 946.0097235007898, 'count': 66, 'avg': 14.333480659102877, 'start': '2000-01-01', 'end': '2000-03-07'}}}, 3: {'partition': 3, 'offset': 202, 'stations': {'D': {'sum': 1796.3902509311622, 'count': 67, 'avg': 26.811794790017345, 'start': '2000-01-01', 'end': '2000-03-08'}, 'G': {'sum': 1874.1214303924266, 'count': 66, 'avg': 28.3957792483701, 'start': '2000-01-01', 'end': '2000-03-07'}, 'M': {'sum': 1455.9522352801282, 'count': 66, 'avg': 22.059882352729215, 'start': '2000-01-01', 'end': '2000-03-07'}}}}
# {2: {'partition': 2, 'offset': 202, 'stations': {'F': {'sum': 1189.508882214415, 'count': 67, 'avg': 17.753863913647987, 'start': '2000-01-01', 'end': '2000-03-08'}, 'I': {'sum': 2815.577672231135, 'count': 66, 'avg': 42.6602677610778, 'start': '2000-01-01', 'end': '2000-03-07'}, 'J': {'sum': 946.0097235007898, 'count': 66, 'avg': 14.333480659102877, 'start': '2000-01-01', 'end': '2000-03-07'}}}, 3: {'partition': 3, 'offset': 203, 'stations': {'D': {'sum': 1796.3902509311622, 'count': 67, 'avg': 26.811794790017345, 'start': '2000-01-01', 'end': '2000-03-08'}, 'G': {'sum': 1918.3824422910354, 'count': 67, 'avg': 28.632573765537842, 'start': '2000-01-01', 'end': '2000-03-08'}, 'M': {'sum': 1455.9522352801282, 'count': 66, 'avg': 22.059882352729215, 'start': '2000-01-01', 'end': '2000-03-07'}}}}
# {4: {'partition': 4, 'offset': 338, 'stations': {'A': {'sum': 2295.820809755785, 'count': 67, 'avg': 34.26598223516097, 'start': '2000-01-01', 'end': '2000-03-08'}, 'B': {'sum': 2890.1276148905476, 'count': 67, 'avg': 43.13623305806787, 'start': '2000-01-01', 'end': '2000-03-08'}, 'C': {'sum': 2728.426837693293, 'count': 67, 'avg': 40.72278862228795, 'start': '2000-01-01', 'end': '2000-03-08'}, 'K': {'sum': 945.9533605382718, 'count': 66, 'avg': 14.3326266748223, 'start': '2000-01-01', 'end': '2000-03-07'}, 'L': {'sum': 1660.9641014656956, 'count': 66, 'avg': 25.166122749480238, 'start': '2000-01-01', 'end': '2000-03-07'}}}, 5: {'partition': 5, 'offset': 68, 'stations': {'H': {'sum': 1365.7417965068475, 'count': 67, 'avg': 20.38420591801265, 'start': '2000-01-01', 'end': '2000-03-08'}}}}
# {2: {'partition': 2, 'offset': 203, 'stations': {'F': {'sum': 1189.508882214415, 'count': 67, 'avg': 17.753863913647987, 'start': '2000-01-01', 'end': '2000-03-08'}, 'I': {'sum': 2872.074531071549, 'count': 67, 'avg': 42.866784045844014, 'start': '2000-01-01', 'end': '2000-03-08'}, 'J': {'sum': 946.0097235007898, 'count': 66, 'avg': 14.333480659102877, 'start': '2000-01-01', 'end': '2000-03-07'}}}, 3: {'partition': 3, 'offset': 203, 'stations': {'D': {'sum': 1796.3902509311622, 'count': 67, 'avg': 26.811794790017345, 'start': '2000-01-01', 'end': '2000-03-08'}, 'G': {'sum': 1918.3824422910354, 'count': 67, 'avg': 28.632573765537842, 'start': '2000-01-01', 'end': '2000-03-08'}, 'M': {'sum': 1455.9522352801282, 'count': 66, 'avg': 22.059882352729215, 'start': '2000-01-01', 'end': '2000-03-07'}}}}
# {2: {'partition': 2, 'offset': 204, 'stations': {'F': {'sum': 1189.508882214415, 'count': 67, 'avg': 17.753863913647987, 'start': '2000-01-01', 'end': '2000-03-08'}, 'I': {'sum': 2872.074531071549, 'count': 67, 'avg': 42.866784045844014, 'start': '2000-01-01', 'end': '2000-03-08'}, 'J': {'sum': 965.0760208956866, 'count': 67, 'avg': 14.404119714860995, 'start': '2000-01-01', 'end': '2000-03-08'}}}, 3: {'partition': 3, 'offset': 203, 'stations': {'D': {'sum': 1796.3902509311622, 'count': 67, 'avg': 26.811794790017345, 'start': '2000-01-01', 'end': '2000-03-08'}, 'G': {'sum': 1918.3824422910354, 'count': 67, 'avg': 28.632573765537842, 'start': '2000-01-01', 'end': '2000-03-08'}, 'M': {'sum': 1455.9522352801282, 'count': 66, 'avg': 22.059882352729215, 'start': '2000-01-01', 'end': '2000-03-07'}}}}
# {4: {'partition': 4, 'offset': 339, 'stations': {'A': {'sum': 2295.820809755785, 'count': 67, 'avg': 34.26598223516097, 'start': '2000-01-01', 'end': '2000-03-08'}, 'B': {'sum': 2890.1276148905476, 'count': 67, 'avg': 43.13623305806787, 'start': '2000-01-01', 'end': '2000-03-08'}, 'C': {'sum': 2728.426837693293, 'count': 67, 'avg': 40.72278862228795, 'start': '2000-01-01', 'end': '2000-03-08'}, 'K': {'sum': 964.2332440146142, 'count': 67, 'avg': 14.391540955442004, 'start': '2000-01-01', 'end': '2000-03-08'}, 'L': {'sum': 1660.9641014656956, 'count': 66, 'avg': 25.166122749480238, 'start': '2000-01-01', 'end': '2000-03-07'}}}, 5: {'partition': 5, 'offset': 68, 'stations': {'H': {'sum': 1365.7417965068475, 'count': 67, 'avg': 20.38420591801265, 'start': '2000-01-01', 'end': '2000-03-08'}}}}
# {4: {'partition': 4, 'offset': 340, 'stations': {'A': {'sum': 2295.820809755785, 'count': 67, 'avg': 34.26598223516097, 'start': '2000-01-01', 'end': '2000-03-08'}, 'B': {'sum': 2890.1276148905476, 'count': 67, 'avg': 43.13623305806787, 'start': '2000-01-01', 'end': '2000-03-08'}, 'C': {'sum': 2728.426837693293, 'count': 67, 'avg': 40.72278862228795, 'start': '2000-01-01', 'end': '2000-03-08'}, 'K': {'sum': 964.2332440146142, 'count': 67, 'avg': 14.391540955442004, 'start': '2000-01-01', 'end': '2000-03-08'}, 'L': {'sum': 1701.0343447635873, 'count': 67, 'avg': 25.388572309904287, 'start': '2000-01-01', 'end': '2000-03-08'}}}, 5: {'partition': 5, 'offset': 68, 'stations': {'H': {'sum': 1365.7417965068475, 'count': 67, 'avg': 20.38420591801265, 'start': '2000-01-01', 'end': '2000-03-08'}}}}
# {2: {'partition': 2, 'offset': 204, 'stations': {'F': {'sum': 1189.508882214415, 'count': 67, 'avg': 17.753863913647987, 'start': '2000-01-01', 'end': '2000-03-08'}, 'I': {'sum': 2872.074531071549, 'count': 67, 'avg': 42.866784045844014, 'start': '2000-01-01', 'end': '2000-03-08'}, 'J': {'sum': 965.0760208956866, 'count': 67, 'avg': 14.404119714860995, 'start': '2000-01-01', 'end': '2000-03-08'}}}, 3: {'partition': 3, 'offset': 204, 'stations': {'D': {'sum': 1796.3902509311622, 'count': 67, 'avg': 26.811794790017345, 'start': '2000-01-01', 'end': '2000-03-08'}, 'G': {'sum': 1918.3824422910354, 'count': 67, 'avg': 28.632573765537842, 'start': '2000-01-01', 'end': '2000-03-08'}, 'M': {'sum': 1472.1311952930184, 'count': 67, 'avg': 21.97210739243311, 'start': '2000-01-01', 'end': '2000-03-08'}}}}
# {0: {'partition': 0, 'offset': 68, 'stations': {'N': {'sum': 2242.255756591567, 'count': 67, 'avg': 33.466503829724886, 'start': '2000-01-01', 'end': '2000-03-08'}}}, 1: {'partition': 1, 'offset': 135, 'stations': {'E': {'sum': 2265.9915975855906, 'count': 67, 'avg': 33.82077011321777, 'start': '2000-01-01', 'end': '2000-03-08'}, 'O': {'sum': 1724.1513799743482, 'count': 66, 'avg': 26.123505757187093, 'start': '2000-01-01', 'end': '2000-03-07'}}}}
# {0: {'partition': 0, 'offset': 68, 'stations': {'N': {'sum': 2242.255756591567, 'count': 67, 'avg': 33.466503829724886, 'start': '2000-01-01', 'end': '2000-03-08'}}}, 1: {'partition': 1, 'offset': 136, 'stations': {'E': {'sum': 2265.9915975855906, 'count': 67, 'avg': 33.82077011321777, 'start': '2000-01-01', 'end': '2000-03-08'}, 'O': {'sum': 1754.1669907654382, 'count': 67, 'avg': 26.18159687709609, 'start': '2000-01-01', 'end': '2000-03-08'}}}}
# {4: {'partition': 4, 'offset': 341, 'stations': {'A': {'sum': 2334.1615793962, 'count': 68, 'avg': 34.32590557935588, 'start': '2000-01-01', 'end': '2000-03-09'}, 'B': {'sum': 2890.1276148905476, 'count': 67, 'avg': 43.13623305806787, 'start': '2000-01-01', 'end': '2000-03-08'}, 'C': {'sum': 2728.426837693293, 'count': 67, 'avg': 40.72278862228795, 'start': '2000-01-01', 'end': '2000-03-08'}, 'K': {'sum': 964.2332440146142, 'count': 67, 'avg': 14.391540955442004, 'start': '2000-01-01', 'end': '2000-03-08'}, 'L': {'sum': 1701.0343447635873, 'count': 67, 'avg': 25.388572309904287, 'start': '2000-01-01', 'end': '2000-03-08'}}}, 5: {'partition': 5, 'offset': 68, 'stations': {'H': {'sum': 1365.7417965068475, 'count': 67, 'avg': 20.38420591801265, 'start': '2000-01-01', 'end': '2000-03-08'}}}}
# exiting
# exiting
# exiting
